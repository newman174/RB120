# %% [markdown]
# # Exercise Set: Easy 2

# %% [markdown]
# ##  1 - Fix the Program - Mailable

# %% [markdown]
# ### Problem Description

# %%
# Given Code

module Mailable
  def print_address
    puts "#{name}"
    puts "#{address}"
    puts "#{city}, #{state} #{zipcode}"
  end
end

class Customer
  attr_reader :name, :address, :city, :state, :zipcode
end

class Employee
  attr_reader :name, :address, :city, :state, :zipcode
end

betty = Customer.new 
bob = Employee.new
betty.print_address
bob.print_address

# %%
# My Solution

module Mailable
  def print_address
    puts "#{name}"
    puts "#{address}"
    puts "#{city}, #{state} #{zipcode}"
  end
end

class Customer
  include Mailable

  attr_reader :name, :address, :city, :state, :zipcode
end

class Employee
  include Mailable
  
  attr_reader :name, :address, :city, :state, :zipcode
end

betty = Customer.new 
bob = Employee.new
betty.print_address
bob.print_address
# Out:
# ,
#
#
# ,

# %%
# Test Cases

# %%
# LS Solution

class Customer
  include Mailable

  attr_reader :name, :address, :city, :state, :zipcode
end

class Employee
  include Mailable

  attr_reader :name, :address, :city, :state, :zipcode
end

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  2 - Fix the Program - Drivable

# %% [markdown]
# ### Problem Description

# %%
# Given Code

module Drivable
  def self.drive
  end
end

class Car
  include Drivable
end

bobs_car = Car.new
bobs_car.drive

# %%
# Test Cases

# %%
# My Solution

module Drivable
  def drive
  end
end

class Car
  include Drivable
end

bobs_car = Car.new
bobs_car.drive

# %%
# LS Solution

def drive
end

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  3 - Complete The Program - Houses

# %% [markdown]
# ### Problem Description

# %%
# Given Code

class House
  attr_reader :price

  def initialize(price)
    @price = price
  end
end

home1 = House.new(100_000)
home2 = House.new(150_000)
puts "Home 1 is cheaper" if home1 < home2
puts "Home 2 is more expensive" if home2 > home1

# %%
# My Solution

class House
  include Comparable
  attr_reader :price

  def initialize(price)
    @price = price
  end

  def <=>(other_house)
    self.price <=> other_house.price
  end
end

home1 = House.new(100_000)
home2 = House.new(150_000)
puts "Home 1 is cheaper" if home1 < home2
puts "Home 2 is more expensive" if home2 > home1
# Out:
# Home 1 is cheaper
# Home 2 is more expensive

# %%
# Test Cases

# Home 1 is cheaper
# Home 2 is more expensive

# %%
# LS Solution

class House
  attr_reader :price
  include Comparable

  def initialize(price)
    @price = price
  end

  def <=>(other)
    price <=> other.price
  end
end

...

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  4 - Reverse Engineering

# %% [markdown]
# ### Problem Description

# %%
# Given Code

# %%
# My Solution

class Transform
  def self.lowercase(str)
    str.downcase
  end

  def initialize(data)
    @data = data
  end

  def uppercase
    @data.upcase
  end
end
# Out:
# :uppercase

# %%
# Test Cases

my_data = Transform.new('abc')
puts my_data.uppercase # => ABC
puts Transform.lowercase('XYZ') # => xyz
# Out:
# ABC
# xyz

# %%
# LS Solution

class Transform
  def initialize(data)
    @data = data
  end

  def uppercase
    @data.upcase
  end

  def self.lowercase(str)
    str.downcase
  end
end

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  5 - What Will This Do?

# %% [markdown]
# ### Problem Description

# %%
# Given Code

class Something
  def initialize
    @data = 'Hello'
  end

  def dupdata
    @data + @data
  end

  def self.dupdata
    'ByeBye'
  end
end

thing = Something.new
puts Something.dupdata
puts thing.dupdata
# Out:
# ByeBye
# HelloHello

# %%
# Test Cases

# %%
# My Solution

# ByeBye
# HelloHello

# %%
# LS Solution

# ByeBye
# HelloHello

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  6 - Comparing Wallets

# %% [markdown]
# ### Problem Description

# %%
# Given Code

class Wallet
  include Comparable

  def initialize(amount)
    @amount = amount
  end

  def <=>(other_wallet)
    amount <=> other_wallet.amount
  end
end

bills_wallet = Wallet.new(500)
pennys_wallet = Wallet.new(465)
if bills_wallet > pennys_wallet
  puts 'Bill has more money than Penny'
elsif bills_wallet < pennys_wallet
  puts 'Penny has more money than Bill'
else
  puts 'Bill and Penny have the same amount of money.'
end

# %%
# Test Cases

# %%
# My Solution

class Wallet
  include Comparable

  def initialize(amount)
    @amount = amount
  end

  protected

  attr_reader :amount

  def <=>(other_wallet)
    amount <=> other_wallet.amount
  end
end

bills_wallet = Wallet.new(500)
pennys_wallet = Wallet.new(465)
if bills_wallet > pennys_wallet
  puts 'Bill has more money than Penny'
elsif bills_wallet < pennys_wallet
  puts 'Penny has more money than Bill'
else
  puts 'Bill and Penny have the same amount of money.'
end
# Out:
# Bill has more money than Penny

# %%
# LS Solution

class Wallet
  ...

  protected

  attr_reader :amount
end

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  7 - Pet Shelter

# %% [markdown]
# ### Problem Description

# %%
# Given Code

butterscotch = Pet.new('cat', 'Butterscotch')
pudding      = Pet.new('cat', 'Pudding')
darwin       = Pet.new('bearded dragon', 'Darwin')
kennedy      = Pet.new('dog', 'Kennedy')
sweetie      = Pet.new('parakeet', 'Sweetie Pie')
molly        = Pet.new('dog', 'Molly')
chester      = Pet.new('fish', 'Chester')

phanson = Owner.new('P Hanson')
bholmes = Owner.new('B Holmes')

shelter = Shelter.new
shelter.adopt(phanson, butterscotch)
shelter.adopt(phanson, pudding)
shelter.adopt(phanson, darwin)
shelter.adopt(bholmes, kennedy)
shelter.adopt(bholmes, sweetie)
shelter.adopt(bholmes, molly)
shelter.adopt(bholmes, chester)
shelter.print_adoptions
puts "#{phanson.name} has #{phanson.number_of_pets} adopted pets."
puts "#{bholmes.name} has #{bholmes.number_of_pets} adopted pets."

# %%
# Test Cases

# P Hanson has adopted the following pets:
# a cat named Butterscotch
# a cat named Pudding
# a bearded dragon named Darwin

# B Holmes has adopted the following pets:
# a dog named Molly
# a parakeet named Sweetie Pie
# a dog named Kennedy
# a fish named Chester

# P Hanson has 3 adopted pets.
# B Holmes has 4 adopted pets.

# %%
# My Solution

class Pet
  attr_accessor :species, :name

  def initialize(species, name)
    self.species = species
    self.name = name
  end
end

class Owner
  attr_accessor :name, :adopted_pets

  def initialize(name)
    self.name = name
    @adopted_pets = []
  end

  def adopt(pet)
    self.adopted_pets.push(pet)
  end

  def number_of_pets
    self.adopted_pets.size
  end

end

class Shelter
  attr_accessor :adopting_owners

  def initialize
    self.adopting_owners = []
  end

  def adopt(owner, pet)
    self.adopting_owners.push(owner) unless self.adopting_owners.include?(owner)
    owner.adopt(pet)
  end

  def print_adoptions
    self.adopting_owners.each do |owner|
      puts "#{owner.name} has adopted the following pets:"
      owner.adopted_pets.each do |pet|
        puts "a #{pet.species} named #{pet.name}"
      end
      puts
    end
  end
end

butterscotch = Pet.new('cat', 'Butterscotch')
pudding      = Pet.new('cat', 'Pudding')
darwin       = Pet.new('bearded dragon', 'Darwin')
kennedy      = Pet.new('dog', 'Kennedy')
sweetie      = Pet.new('parakeet', 'Sweetie Pie')
molly        = Pet.new('dog', 'Molly')
chester      = Pet.new('fish', 'Chester')

phanson = Owner.new('P Hanson')
bholmes = Owner.new('B Holmes')

shelter = Shelter.new
shelter.adopt(phanson, butterscotch)
shelter.adopt(phanson, pudding)
shelter.adopt(phanson, darwin)
shelter.adopt(bholmes, kennedy)
shelter.adopt(bholmes, sweetie)
shelter.adopt(bholmes, molly)
shelter.adopt(bholmes, chester)
shelter.print_adoptions
puts "#{phanson.name} has #{phanson.number_of_pets} adopted pets."
puts "#{bholmes.name} has #{bholmes.number_of_pets} adopted pets."
# Out:
# P Hanson has adopted the following pets:
# a cat named Butterscotch
# a cat named Pudding
# a bearded dragon named Darwin
#
# B Holmes has adopted the following pets:
# a dog named Kennedy
# a parakeet named Sweetie Pie
# a dog named Molly
# a fish named Chester
#
# P Hanson has 3 adopted pets.
# B Holmes has 4 adopted pets.

# %%
# LS Solution

class Pet
  attr_reader :animal, :name

  def initialize(animal, name)
    @animal = animal
    @name = name
  end

  def to_s
    "a #{animal} named #{name}"
  end
end

class Owner
  attr_reader :name, :pets

  def initialize(name)
    @name = name
    @pets = []
  end

  def add_pet(pet)
    @pets << pet
  end

  def number_of_pets
    pets.size
  end

  def print_pets
    puts pets
  end
end

class Shelter
  def initialize
    @owners = {}
  end

  def adopt(owner, pet)
    owner.add_pet(pet)
    @owners[owner.name] ||= owner
  end

  def print_adoptions
    @owners.each_pair do |name, owner|
      puts "#{name} has adopted the following pets:"
      owner.print_pets
      puts
    end
  end
end

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  8 - Fix The Program - Expander

# %% [markdown]
# ### Problem Description

# %% [markdown]
# THIS PROBLEM DEMONSTRATES SOMETHING THAT IS NOT AN ISSUE IN RECENT RUBY VERSIONS

# %%
# Given Code

class Expander
  def initialize(string)
    @string = string
  end

  def to_s
    self.expand(3)
  end

  private

  def expand(n)
    @string * n
  end
end

expander = Expander.new('xyz')
puts expander
# Out:
# xyzxyzxyz

# %%
# Test Cases

# %%
# My Solution

class Expander
  def initialize(string)
    @string = string
  end

  def to_s
    self.expand(3)
  end

  private

  def expand(n)
    @string * n
  end
end

expander = Expander.new('xyz')
puts expander
# Out:
# xyzxyzxyz

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  9 - Moving

# %% [markdown]
# ### Problem Description

# %%
# Given Code

class Person
  attr_reader :name

  def initialize(name)
    @name = name
  end

  private

  def gait
    "strolls"
  end
end

class Cat
  attr_reader :name

  def initialize(name)
    @name = name
  end

  private

  def gait
    "saunters"
  end
end

class Cheetah
  attr_reader :name

  def initialize(name)
    @name = name
  end

  private

  def gait
    "runs"
  end
end

# %%
# My Solution

module Walkable
  def walk
    "#{name} #{gait} forward"
  end
end

class Person
  include Walkable

  attr_reader :name

  def initialize(name)
    @name = name
  end

  private

  def gait
    "strolls"
  end
end

class Cat
  include Walkable

  attr_reader :name

  def initialize(name)
    @name = name
  end

  private

  def gait
    "saunters"
  end
end

class Cheetah
  include Walkable

  attr_reader :name

  def initialize(name)
    @name = name
  end

  private

  def gait
    "runs"
  end
end
# Out:
# :gait

# %%
# Test Cases

mike = Person.new("Mike")
puts mike.walk
# => "Mike strolls forward"

kitty = Cat.new("Kitty")
puts kitty.walk
# => "Kitty saunters forward"

flash = Cheetah.new("Flash")
puts flash.walk
# => "Flash runs forward"
# Out:
# Mike strolls forward
# Kitty saunters forward
# Flash runs forward

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ## 10 - Nobility

# %% [markdown]
# ### Problem Description

# %%
# Given Code

module Walkable
  def walk
    "#{name} #{gait} forward"
  end
end

class Person
  include Walkable

  attr_reader :name

  def initialize(name)
    @name = name
  end

  private

  def gait
    "strolls"
  end
end

class Cat
  include Walkable

  attr_reader :name

  def initialize(name)
    @name = name
  end

  private

  def gait
    "saunters"
  end
end

class Cheetah
  include Walkable

  attr_reader :name

  def initialize(name)
    @name = name
  end

  private

  def gait
    "runs"
  end
end
# Out:
# :gait

# %%
# My Solution

module Walkable
  def walk
    "#{name} #{gait} forward"
  end
end

class Noble
  attr_reader :name, :title

  include Walkable

  def initialize(name, title)
    @name = name
    @title = title
  end

  # def walk
  #   name = "#{title} #{name}"
    
  # end

  def gait
    'struts'
  end

end
# Out:
# :gait

# %%
# Test Cases

byron = Noble.new("Byron", "Lord")
p byron.walk
# => "Lord Byron struts forward"

p byron.name
# => "Byron"
p byron.title
# => "Lord"
# Out:
# "Lord "
# "Byron"
# "Lord"
# "Lord"

# %%
# LS Solution

# %% [markdown]
# ### Discussion
