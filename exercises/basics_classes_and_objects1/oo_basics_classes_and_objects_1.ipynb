# %% [markdown]
# # Exercise Set: OO Basics: Classes and Objects 1

# %% [markdown]
# ##  1 - Find the Class

# %% [markdown]
# ### Problem Description

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  2 - Create the Class

# %% [markdown]
# ### Problem Description

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  3 - Create the Object

# %% [markdown]
# ### Problem Description

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  4 - What Are You?

# %% [markdown]
# ### Problem Description

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  5 - Hello, Sophie! (Part 1)

# %% [markdown]
# ### Problem Description

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  6 - Hello, Sophie! (Part 2)

# %% [markdown]
# ### Problem Description

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  7 - Reader

# %% [markdown]
# ### Problem Description

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  8 - Writer

# %% [markdown]
# ### Problem Description

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  9 - Accessor

# %% [markdown]
# ### Problem Description

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ## 10 - Walk the Cat

# %% [markdown]
# ### Problem Description

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion
