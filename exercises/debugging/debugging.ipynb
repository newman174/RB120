# %% [markdown]
# # Exercise Set: Debugging

# %% [markdown]
# ##  1 - Community Library

# %% [markdown]
# ### Problem Description

# %%
# Given Code

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  2 - Animal Kingdom

# %% [markdown]
# ### Problem Description

# %%
# Given Code

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  3 - Wish You Were Here

# %% [markdown]
# ### Problem Description

# %%
# Given Code

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  4 - Employee Management

# %% [markdown]
# ### Problem Description

# %%
# Given Code

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  5 - Files

# %% [markdown]
# ### Problem Description

# %%
# Given Code

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  6 - Sorting Distances

# %% [markdown]
# ### Problem Description

# %%
# Given Code

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  7 - Bank Balance

# %% [markdown]
# ### Problem Description

# %%
# Given Code

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  8 - Task Manager

# %% [markdown]
# ### Problem Description

# %%
# Given Code

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ##  9 - You've Got Mail!

# %% [markdown]
# ### Problem Description

# %%
# Given Code

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion

# %% [markdown]
# ## 10 - Does it Rock or Not?

# %% [markdown]
# ### Problem Description

# %%
# Given Code

# %%
# Test Cases

# %%
# My Solution

# %%
# LS Solution

# %% [markdown]
# ### Discussion
